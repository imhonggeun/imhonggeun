# %%
print(1 + 2)
print(1 - 2)
print(1 * 2)
print(1 / 2)
a = 1
b = 2
c = 3
값 = a+b-c
print("이름:{값}")
print(1 + -1)
a = 7%3
print(a)
a=5
a+=2
print(a)
print(b)
print(c)
# Out:
# 3
# -1
# 2
# 0.5
# 이름:{값}
# 0
# 1
# 7
# 2
# 3
# 3
