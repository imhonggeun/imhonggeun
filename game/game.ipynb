# %% [markdown]
# 반복문에서 사용되는 기능
#
# break : 강제로 종료
# continue : 다음으로 점프

# %% [markdown]
# 1.break 사용 예시

# %%
변수 = 0
while True:
    변수 +=1
    if 변수 == 5:
        break
    else:
        print(변수)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# 2.continue 사용 예시

# %%
변수 = 0
while 변수 <5:
    변수 +=1
    if 변수%2 ==0:
        continue
    else:
        print(변수)
# Out:
# 1
# 3
# 5
