# %% [markdown]
# 파이썬에서 사용하는 기본 자료형과 변수

# %%
# 숫자
a = 100 + 36
print(a)

# %%
# 문자열
a = '문자열' + '\t' + "'출력' 하세요."
print(a)

# %%
a = '내용이 들어 있습니다.'
print(a[2])
print(a[:3])

# %%
a = '내용이 들어 있습니다.'
print(len(a), a[-5:], a[-5:len(a)])

# %%
a = '내용이 들어 있습니다.'
print(a, type(a))

# %% [markdown]
# 어제 내용 복습 6월 18일 내용
