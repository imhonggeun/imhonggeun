# %%
a = 'X'
b = 'O'
for y in range(5):
    조합 = ''
    for x in range(5):
        # 문자가 조합 되는 코드 작성
        if (y == 0 or y==4) and x == 2:
            조합 += b
        elif (y == 1 or y==3) and (x == 1 or x == 2 or x == 3) :
            조합 += b
        elif y == 2:
            조합 += b
        #elif y == 3 and (x==1 or x==2 or x==3):
         #   조합 += b
        #elif y == 4 and x == 2:
         #   조합 += b
        else:
            조합 += a
    # 조합 된 문자 출력
    print(조합)
# Out:
# XXOXX
# XOOOX
# OOOOO
# XOOOX
# XXOXX

# %%
a = 'x'
b = 'o'
for y in range(10):
    블럭 = ''
    for x in range(10):
        if (y == 0 or y == 9) and (x==0 or x==9): #1,10번째
            블럭 +=b
        
        elif (y == 1 or y == 8) and (x==1 or x==8): #2,9번째
            블럭 +=b
            
        elif (y == 2 or y == 7) and (x==2 or x==7): #3,8번째
            블럭 +=b
            
        elif (y == 3 or y == 6) and (x==3 or x==6): #4,7번째
            블럭 +=b
                
        elif (y == 4 or y == 5) and (x==4 or x==5): #5,6번째
            블럭 +=b
        
        else:
            블럭 +=a
    print(블럭)
# Out:
# oxxxxxxxxo
# xoxxxxxxox
# xxoxxxxoxx
# xxxoxxoxxx
# xxxxooxxxx
# xxxxooxxxx
# xxxoxxoxxx
# xxoxxxxoxx
# xoxxxxxxox
# oxxxxxxxxo

# %%
a = 'x'
b = '■'
for y in range(10):
    블럭 = ''
    for x in range(10):
        if (y == 0 or y == 9) and (x==0 or x==9): #1,10번째
            블럭 +=b
        
        elif (y == 1 or y == 8) and (x==1 or x==8): #2,9번째
            블럭 +=b
            
        elif (y == 2 or y == 7) and (x==2 or x==7): #3,8번째
            블럭 +=b
            
        elif (y == 3 or y == 6) and (x==3 or x==6): #4,7번째
            블럭 +=b
                
        elif (y == 4 or y == 5) and (x==4 or x==5): #5,6번째
            블럭 +=b
        
        else:
            블럭 +=a
    print(블럭)
# Out:
# ■xxxxxxxx■
# x■xxxxxx■x
# xx■xxxx■xx
# xxx■xx■xxx
# xxxx■■xxxx
# xxxx■■xxxx
# xxx■xx■xxx
# xx■xxxx■xx
# x■xxxxxx■x
# ■xxxxxxxx■

# %%
a = 'X'
b = 'O'
for y in range(10):
    조합 = ''
    for x in range(10):
        if x == y or x + y == 9:
            조합 += b
        else:
            조합 += a

    print(조합)
# Out:
# OXXXXXXXXO
# XOXXXXXXOX
# XXOXXXXOXX
# XXXOXXOXXX
# XXXXOOXXXX
# XXXXOOXXXX
# XXXOXXOXXX
# XXOXXXXOXX
# XOXXXXXXOX
# OXXXXXXXXO
