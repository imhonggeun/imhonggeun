# %%
a = []
print(type(a))
# Out:
# <class 'list'>

# %%
a = []
a.append(10)
print(a)
print(a[0])
a[0] = 5
print(a)
# Out:
# [10]
# 10
# [5]

# %%
a = []
a.append(1)
a.append(2)
a.append(3)
a.append(4)
print(a[2])
# Out:
# 3

# %%
for 변수 in a:
    print(변수)
# Out:
# 1
# 2
# 3
# 4

# %%
b = range(1,5)
for 변수 in b :
    print(변수)
# Out:
# 1
# 2
# 3
# 4

# %%
print(type(a))
print(type(b))
# Out:
# <class 'list'>
# <class 'range'>

# %%
for 인덱스 in range(0,4):
    print(f"{a[0]} * {b[1]} = {a[1] * b[1]}")
# Out:
# 1 * 2 = 4
# 1 * 2 = 4
# 1 * 2 = 4
# 1 * 2 = 4
