# %% [markdown]
# 제어문
#
#     1.조건문:if
#     2.반복문:for,while

# %%
a = 5
print(a == 3)
# Out:
# False

# %%
#a는 10이이고 == 비교로 3이 맞는지 화인
#1 a=10==10
a=10==3
if a:
    print('맞다') #1 으로 진행 할땐 해당 값 표시
else:
    print('틀리다') #10과3을 비교했을 때 값이 다르니까 틀리다 표현
# Out:
# 틀리다
