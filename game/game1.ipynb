# %%
a = [] #list 
print(type(a))
# Out:
# <class 'list'>

# %%
a = [1,2,3,4,5]
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
for b in a:
    print(b)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for b in range(4,10):
    print(b)
# Out:
# 4
# 5
# 6
# 7
# 8
# 9
