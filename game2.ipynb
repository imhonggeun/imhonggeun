# %%
a = 10 == 3
b='맞다' if a else '다르다'
print(b)
# Out:
# 다르다

# %%
지갑 = 10000
피씨방 = 1000
라면 = 2000
음료수 = 1500
# 금액 = 4500 고정
지불할금액 = int(input('지불할금액을 입력하세요')) # input 으로 받을 값을 변경 가능하고 int로 숫자로 변경
if 지불할금액 == 피씨방 + 라면 + 음료수 :
    print('감사합니다')
else :
    print('거스름돈이 달라요')
# Out:
# 감사합니다

# %%
지갑 = 10000
피씨방 = 1000
라면 = 2000
음료수 = 1500
음식 = int(input('입력하세요'))
남은금액 = 지갑 - 음식
if 지갑 == 음식 :
    print('감사합니다')
else :
    print(남은금액)
# Out:
# 9000

# %%
지갑 = 10000
피씨방 = 1000
라면 = 2000
음료수 = 1500
음식 = int(input('입력하세요'))
남은금액 = 지갑 - 음식
#print(f"{남은금액}원 남았습니다")
print(int(남은금액)+"원 남았습니다")
