# %%
a = [] #리스트
b = () #튜플
print(type(a))
print(type(b))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
a.append(1) #a 리스트에서 위치값을가지고온다
print(a)
# Out:
# [1]

# %%
# b.append(1) 튜플은 append가 없다
print(b)
# Out:
# ()

# %%
b = (1,2,3) #튜플
print(b)
# Out:
# <class 'tuple'>
# (1, 2, 3)

# %%
a[0] = 10
print(a[0]) #위치 값 가지고 오는것
# Out:
# 10

# %%
# b[0] = 10 위치값을 변경 불가능하다
print(b[0]) # 위치값을 가지고 오는 건 가능하다
# Out:
# 1
