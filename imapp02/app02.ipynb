# %% [markdown]
# 문제1 10 20 30 을 리스트로 만들어 출력하세요
# 문제2 만들어진 리스트에서 가장 중간요소 20 만 출력하세요
# 문제3 append를 사용하여 리스트에 요소 40을 추가하고 출력하세요.
# 문제4 리스트의 요소 30과 40을 출력하세요.
# 문제5 리스트의 요소 40을 remove를 사용해서 제거하고 출력하세요.
# 문제6 리스트의 요소중 30을 40으로 바꾸고 출력하세요.
# 문제7 리스트의 요소중 20을 튜플의 형태로 만들고 변형시켜보세요. 변형시키지 못하고 오류가 나와야 정답입니다

# %%
a = [10,(20,),30]
print(a)
print(a[1])
a.append(40)
print(a)
print(a[2],a[3])
a.remove(40)
print(a)
a[2] = 40
print(a[2])
a[1][0] = 30
print(a[1])
# Out:
# [10, (20,), 30]
# (20,)
# [10, (20,), 30, 40]
# 30 40
# [10, (20,), 30]
# 40
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 11
#       9 a[2] = 40
#      10 print(a[2])
# ---> 11 a[1][0] = 30
#      12 print(a[1])
#
# TypeError: 'tuple' object does not support item assignment
